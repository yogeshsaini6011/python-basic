# %% [markdown]
# # day 1 ka kaam

# %% [markdown]
# ## String & Indexing

# %%
name = "yogesh"

name
# Out:
# 'yogesh'

# %%
x = "Python"
print(x[0],"is the first element")
# Out:
# P is the first element

# %%
x ='Programming'
print(x[-1],"is the last element")
# Out:
# g is the last element

# %%
text = 'Developer'
print(text[3],"is the 3 element")
# Out:
# e is the 3 element

# %% [markdown]
# ### What will be the output? word = 'Python' print(word[-2])

# %% [markdown]
# #### solution = 0

# %% [markdown]
# ## Length & Case Methods

# %%
a ='Artificial Intelligence'
print(len(a),"is the length of ",a )
# Out:
# 46 is the length of  Artificial IntelligenceArtificial Intelligence

# %%
a = 'python programming'
print(a.upper(),"in upper case")
print(a.title(),"in title")
print(a.lower(),"in lower case")
# Out:
# PYTHON PROGRAMMING in upper case
# Python Programming in title
# python programming in lower case

# %%
a = input("enter a strinng")
print(len(a))
print(a.upper(),"in upper case")
print(a.lower(),"in lower case")
print(a.title(),"in title")
# Out:
# enter a strinng hbu
# 3
# HBU in upper case
# hbu in lower case
# Hbu in title

# %% [markdown]
# ## Searching & Counting

# %%
a='banana'
print(a.count(a) ,"is the index value of a in ",a)
# Out:
# 1 is the index value of a in  banana

# %%
a ='I love data science'
print(a.find('data'),"is the index of  data in",a)
# Out:
# 7 is the index of  data in I love data science

# %% [markdown]
# #### Explain the difference between find() and index() when value is not found

# %% [markdown]
# #### sol
# main diff is that find() does not throws error while index throws an error() when thee string or data is not present

# %% [markdown]
# ## Startswith & Endswith

# %%
a ='python.py'
print( a,"ends with .py-",a.endswith('.py'))
# Out:
# python.py ends with .py- True

# %%
a ='https://google.com'
print(a,"starts with https -",a.startswith('https'))
# Out:
# https://google.com starts with https True

# %%
a =input("enter a name")
print(a,"starts with mr -",a.startswith('mr'))
# Out:
# enter a name kn
# kn starts with mr - False

# %% [markdown]
# ## Validation Methods

# %%
a = 'Python123'
print(a.isalnum())
# Out:
# True

# %% [markdown]
# a ='s'
# print(a.isspace())

# %%
a ='hello'
print(a.islower())
# Out:
# True

# %%
a ='HELLO'
print(a.isupper())
# Out:
# True

# %%
a =  'Python Programming'
print(a.istitle())
# Out:
# True

# %% [markdown]
# ## Strip Methods

# %%
a=   ' Python'
print(a.strip())
# Out:
# Python

# %%
a = "Python "
print(a.strip())
# Out:
# Python

# %%
a = ' Python '
print(a.strip())
# Out:
# Python

# %% [markdown]
# ## Replace, Join & Split

# %%
a =  'I love Java'
print(a.replace("Java","python"))
# Out:
# I love python

# %%
a =  'user@email.com'
print(a.partition('@'))
# Out:
# ('user', '@', 'email.com')

# %% [markdown]
# #### What will be the output? text = 'Python-is-fun' print(text.partition('-'))
#     sol output =
#     ('Python','-','is-fun')

# %% [markdown]
# ## User Input Based

# %%
a = input("enter a string")
print(a.isupper())
print(a.isalpha())
# Out:
# enter a string wss
# False
# True

# %%
a=input("enter email")
print(a[0].isalpha())
print(a.endswith(".com"))
# Out:
# enter email huvbu
# True
# False

# %% [markdown]
# ## Bonus Mini Task

# %%
a= input("username")
a.strip()
print(a.isalnum())
print(a[0].isalpha())
# Out:
# username bdubsq33
# True
# True

# %%
print("a")
# Out:
# a
