# %% [markdown]
# # day 3 ka kaam

# %% [markdown]
# ## Assignment Operators

# %%
# What is an assignment operator in Python?
#assignment operators are the operators that are used for mathametical operations in the existing variable for  eg  : +=,-=,*= ,/= ,*=

# %%
# What will be the output? x = 10 x += 5 print(x)
# output = 15

# %%
# Write a program to increase a number by 10 using an assignment operator.
a = int(input("enter a number"))
a+=a
print(a)
# Out:
# enter a number 12
# 24

# %% [markdown]
# ## Arithmetic Operator

# %%
# What is the difference between / and // ?
# diff between / and // is that both are used to divide and  / gives the proper vvalue of division (quotiont) in decimal(float) where as
# // gives only integer value

# %%
#Predict the output: print(10 + 3 * 2)
# output= 16

# %%
# Write a program to check whether a number is even or odd.
a = int(input("eenter a number"))
print(f"the number {a} is even ?? {a%2==0}")
print(f"the number {a} is odd ?? {a%2!=0}")
# Out:
# eenter a number 23
# the number 23 is even ?? False
# the number 23 is odd ?? True

# %% [markdown]
# ## Comparison Operators

# %%
# What is the difference between = and == ?
# = is used to asign value in a variable whereas == is used to check the value is (equal to)

# %%
# What will be the output? print(8 >= 10)
# output = false

# %% [markdown]
# ## Logical Operators

# %%
# Explain AND, OR, and NOT operators.
# sol:  and operator checks all the  values whereas OR only check one value if its true it will not check  other values and if it is false then it will check
# the other values whereas not operator is used to reverse the value means if its true then it will tturn it into false

# %%
# Predict the output: print(5 > 3 and 10 < 20)
# output : true

# %%
# Write a program to check voting eligibility.
age = int(input("enter your age"))
n = input("enter your nationality")
print(f"are you elegible for voting ?? {age>=18 and n.upper()=="INDIAN"}")
# Out:
# enter your age 18
# enter your nationality indian
# are you elegible for voting ?? True

# %% [markdown]
# ## Bitwise Operators

# %%
# What are bitwise operators?

# %%
# What will be the output? print(5 & 3)

# %%
# Write a program to perform bitwise OR on two numbers.

# %% [markdown]
# # Identity Operators

# %%
# What is the difference between IS and == ?
# solution :  IS operator is used to check the object value differnt in list and  strings whereas == checks the value (is equal)

# %%
# Predict the output: a = 10 b = 10 print(a is b)
# sol : true (because integer have equal object value)

# %% [markdown]
# ##  Membership Operators

# %%
# What are membership operators?
# membership operators are the operator that are used to check element exist in string ,list dict,set...etc... or not
# 'in' is  the membership operator

# %%
# What will be the output? print('a' in 'apple')
#output :  true

# %%
a = 'apple'
print(f"is a exist in {a} ? {'a' in a}")
# Out:
# is a exist in apple ? True
