# %% [markdown]
# # kaam

# %% [markdown]
# ##  Variables (Basic Practice)

# %%
# Create a variable name and store your name in it. Print the value.
name = 'yogesh'
print(name)
# Out:
# yogesh

# %%
# Create a variable price and store 99.50 in it. Print the value
price = 99.50
print(price)
# Out:
# 99.5

# %%
#Create three variables a = 10, b = 20, c = 30 and print their sum.
a=10
b=30
c=90
print(a+b+c)
# Out:
# 130

# %% [markdown]
# ##  User Input (Basics)

# %%
 # Take the user’s name as input and print: Hello
a =input("enter your name")
print(f"hello{a}")
# Out:
# enter your name usbu
# hellousbu

# %%
#Take the user’s age as input and print: Your age is
age = int(input("enter your age"))
print(f"your age is {age}")
# Out:
# enter your age 112
# your age is 112

# %%
#Take the user’s city name as input and print: You live in
a = input("enter your city name")
print(f"you live in {a}")
# Out:
# enter your city name assan
# you live in assan

# %%
#Take the user’s favorite number as input and print it. Part 3
a= int(input("enter favorite number "))
print(f"your favorite number is {a}")
# Out:
# enter favorite number  12
# your favorite number is 12

# %% [markdown]
# ## Type Casting

# %%
# 1 Take a number from the user and print its square.
a = int(input("enter a nummber"))
print(f"square = {a*a} ")
# Out:
# enter a nummber 21
# square = 441

# %%
# Take two numbers from the user and print their addition.
a=int(input("enter first number "))
b=int(input("enter  second number "))
print(f"sum = {a+b}")
# Out:
# enter first number  12
# enter  second number  1
# sum = 13

# %%
#Take a number as input, print its type, convert it into an integer, and print its type again.
a=input("enter a number")
print(type(a))
b=int(a)
print(type(b))
# Out:
# enter a number 1212
# <class 'str'>
# <class 'int'>

# %%
#Take a decimal number from the user, convert it into an integer, and print it.
a = float(input("enter a decimal number"))
b=int(a)
print(b)
# Out:
# enter a decimal number 121.3123
# 121

# %% [markdown]
# ## Mixed Questions

# %%
# Take name and age from the user and print: My name is Rahul and I am 20 years old.
a = input("enter your name")
b = int(input("enter your agee"))
print(f"my name is {a} and i am  {b} year old")
# Out:
# enter your name yogesh
# enter your agee 20
# my name is yogesh and i am  20 year old

# %%
#Take length and breadth from the user and calculate the area of a rectangle.
a=int(input("enter length of  rectangle"))
b= int(input("enter breadth of rectangle"))
print(f"area of rctangle is {a*b}")
# Out:
# enter length of  rectangle 12
# enter breadth of rectangle 12
# area of rctangle is 144

# %%
# Take three numbers from the user and calculate their average.
a = int(input("enter a number"))
b = int(input("enter a number"))
c= int(input("enter a number"))
print(f"average of {a} {b} {c} is {(a+b+c)/3} ")
# Out:
# enter a number 1
# enter a number 2
# enter a number 3
# average of 1 2 3 is 2.0

# %% [markdown]
# ##  Concept Check

# %%
# What will be the output of: x = "10", y = "20", print(x + y)?
# output of  this question is 30

# %%
# Why will this code give an error? a = input("Enter number"); print(a + 5)
#  no this code will not give an error

# %%
#  What is the difference between int("10") and float("10")?
# diff = int is variable for integer and float is for decimal values

# %%
# In which data type does input() always take user input?
# in string

# %% [markdown]
# ## Bonus Mini Project

# %%
 # Create a Student Information program that takes Name, Roll Number, and Marks from the user and prints them properly.
name = input("enter your name")
roll = input("enter your roll number")
marks = input("enter your marks")
print(f"my name is {name} and my roll no is {roll} and my total marks are {marks}")
# Out:
# enter your name yogesh
# enter your roll number 11242514
# enter your marks 1233
# my name is yogesh  and my is 11242514 and my total marks are 1233
